# %%
# !pip install -q transformers datasets controlnet_aux

# %%
from controlnet_aux import LineartDetector
processor = LineartDetector.from_pretrained("lllyasviel/Annotators")
# Out:
# /opt/conda/lib/python3.10/site-packages/controlnet_aux/mediapipe_face/mediapipe_face_common.py:7: UserWarning: The module 'mediapipe' is not installed. The package will have limited functionality. Please install it using the command: pip install 'mediapipe'
#   warnings.warn(
# sk_model.pth:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# sk_model2.pth:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/controlnet_aux/lineart/__init__.py:112: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
# /opt/conda/lib/python3.10/site-packages/controlnet_aux/lineart/__init__.py:116: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   coarse_model.load_state_dict(torch.load(coarse_model_path, map_location=torch.device('cpu')))

# %%
from datasets import load_dataset
ds = load_dataset("Subh775/Filtered_Movies_Caption_Dataset", split='train')
# Out:
# README.md:   0%|          | 0.00/3.51k [00:00<?, ?B/s]
# train-00000-of-00004.parquet:   0%|          | 0.00/439M [00:00<?, ?B/s]
# train-00001-of-00004.parquet:   0%|          | 0.00/432M [00:00<?, ?B/s]
# train-00002-of-00004.parquet:   0%|          | 0.00/432M [00:00<?, ?B/s]
# train-00003-of-00004.parquet:   0%|          | 0.00/425M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5384 [00:00<?, ? examples/s]

# %%
ds
# Out:
# Dataset({
#     features: ['image', 'caption'],
#     num_rows: 5384
# })

# %%
ds[4598]["caption"]
#ds2[2796]["caption"]
# Out:
# '"The image is a poster for the movie ""The Swamp"". The main design elements include a large, domed building with a dome, which is the central focus of the poster. The colors used are predominantly dark and moody, creating a sense of mystery and foreboding. The layout of the poster features the title ""The Swamp"" prominently displayed in large, bold letters at the bottom. There is no additional text or design elements that are promotional or filler text."'

# %%
#RGB image
ds[4598]['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=480x480>

# %%
#Conditional image 
processor(ds[4598]['image'])
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from tqdm import tqdm
import time 

captions = []
images = []
conditional_images = []

for example in tqdm(ds, desc="Processing images"):
    caption = example['caption']
    image = example['image']
    
    # Assuming you have a `processor` function that processes the image
    conditional_image = processor(image)

    # Append the processed data to the lists
    captions.append(caption)
    images.append(image)
    conditional_images.append(conditional_image)

processed_data = {
    'captions': captions,
    'images': images,
    'conditional_images': conditional_images
}

# Verify the result
print(f"Processed {len(captions)} samples.")

# Start timing
start_time = time.time()

def process_image(example):
    example['conditional_image'] = processor(example['image'])
    return example


ds = ds.map(process_image)

#ds.push_to_hub("Subh775/Changing_Movies_Poster_Dataset", token="Enter_your_hf_tokens_here", split="train")
ds.push_to_hub("Subh775/Conditional_Movies_Poster_Dataset",token="Enter_your_hf_tokens_here", split="train") 

# Measure elapsed time
elapsed_time = time.time() - start_time
print(f"Time elapsed: {elapsed_time:.2f} seconds")

# !pkill jupyter
# Out:
# Processing images: 100%|██████████| 5384/5384 [3:43:06<00:00,  2.49s/it]
# Processed 5384 samples.
# Map:   0%|          | 0/5384 [00:00<?, ? examples/s]
# Uploading the dataset shards:   0%|          | 0/6 [00:00<?, ?it/s]
# Map:   0%|          | 0/898 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/9 [00:00<?, ?ba/s]
# Map:   0%|          | 0/898 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/9 [00:00<?, ?ba/s]
# Map:   0%|          | 0/897 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/9 [00:00<?, ?ba/s]
# Map:   0%|          | 0/897 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/9 [00:00<?, ?ba/s]
# Map:   0%|          | 0/897 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/9 [00:00<?, ?ba/s]
# Map:   0%|          | 0/897 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/9 [00:00<?, ?ba/s]
# Time elapsed: 13942.81 seconds
